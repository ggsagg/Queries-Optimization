// %%
import $file.common
import spark._
import common._
import org.apache.spark.sql.functions._
import org.apache.spark.sql.types.{IntegerType, StringType, StructType}
// Out:
// Loading spark-stubs
// Getting spark JARs
// log4j:WARN No appenders could be found for logger (org.eclipse.jetty.util.log).
// log4j:WARN Please initialize the log4j system properly.
// log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
// Creating SparkSession
// Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
// 21/06/16 15:20:46 INFO SparkContext: Running Spark version 2.4.5
// 21/06/16 15:20:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
// 21/06/16 15:20:46 INFO SparkContext: Submitted application: Queries Optimization
// 21/06/16 15:20:46 INFO SecurityManager: Changing view acls to: jovyan
// 21/06/16 15:20:46 INFO SecurityManager: Changing modify acls to: jovyan
// 21/06/16 15:20:46 INFO SecurityManager: Changing view acls groups to:
// 21/06/16 15:20:46 INFO SecurityManager: Changing modify acls groups to:
// 21/06/16 15:20:46 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(jovyan); groups with view permissions: Set(); users  with modify permissions: Set(jovyan); groups with modify permissions: Set()
// 21/06/16 15:20:47 INFO Utils: Successfully started service 'sparkDriver' on port 36867.
// 21/06/16 15:20:47 INFO SparkEnv: Registering MapOutputTracker
// 21/06/16 15:20:47 INFO SparkEnv: Registering BlockManagerMaster
// 21/06/16 15:20:47 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
// 21/06/16 15:20:47 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
// 21/06/16 15:20:47 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-f7c52d4a-458f-4306-8acd-7af14bbca413
// 21/06/16 15:20:47 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
// 21/06/16 15:20:47 INFO SparkEnv: Registering OutputCommitCoordinator
// 21/06/16 15:20:47 INFO Utils: Successfully started service 'SparkUI' on port 4043.
// 21/06/16 15:20:47 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://889bd5fba3d9:4043
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/jitpack.io/com/github/jupyter/jvm-repr/0.4.0/jvm-repr-0.4.0-sources.jar at spark://889bd5fba3d9:36867/jars/jvm-repr-0.4.0-sources.jar with timestamp 1623856847526
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/jitpack.io/com/github/jupyter/jvm-repr/0.4.0/jvm-repr-0.4.0.jar at spark://889bd5fba3d9:36867/jars/jvm-repr-0.4.0.jar with timestamp 1623856847528
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/repo1.maven.org/maven2/com/github/scopt/scopt_2.12/3.7.1/scopt_2.12-3.7.1-sources.jar at spark://889bd5fba3d9:36867/jars/scopt_2.12-3.7.1-sources.jar with timestamp 1623856847528
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/repo1.maven.org/maven2/com/github/scopt/scopt_2.12/3.7.1/scopt_2.12-3.7.1.jar at spark://889bd5fba3d9:36867/jars/scopt_2.12-3.7.1.jar with timestamp 1623856847529
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/repo1.maven.org/maven2/com/lihaoyi/ammonite-interp-api_2.12.10/1.7.4/ammonite-interp-api_2.12.10-1.7.4-sources.jar at spark://889bd5fba3d9:36867/jars/ammonite-interp-api_2.12.10-1.7.4-sources.jar with timestamp 1623856847529
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/repo1.maven.org/maven2/com/lihaoyi/ammonite-interp-api_2.12.10/1.7.4/ammonite-interp-api_2.12.10-1.7.4.jar at spark://889bd5fba3d9:36867/jars/ammonite-interp-api_2.12.10-1.7.4.jar with timestamp 1623856847529
// 21/06/16 15:20:47 INFO SparkContext: Added JAR file:/home/jovyan/.cache/coursier/v1/https/repo1.maven.org/maven2/com/lihaoyi
utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 34143.
// 21/06/16 15:20:47 INFO NettyBlockTransferService: Server created on 889bd5fba3d9:34143
// 21/06/16 15:20:47 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
// 21/06/16 15:20:47 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 889bd5fba3d9, 34143, None)
// 21/06/16 15:20:47 INFO BlockManagerMasterEndpoint: Registering block manager 889bd5fba3d9:34143 with 366.3 MB RAM, BlockManagerId(driver, 889bd5fba3d9, 34143, None)
// 21/06/16 15:20:47 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 889bd5fba3d9, 34143, None)
// 21/06/16 15:20:47 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 889bd5fba3d9, 34143, None)
// <a target="_blank" href="http://889bd5fba3d9:4043">Spark UI</a>
// import $file.$
//
// import spark._
//
// import common._
//
// import org.apache.spark.sql.functions._
//
// import org.apache.spark.sql.types.{IntegerType, StringType, StructType}

// %%
import spark.implicits._
import spark.sqlContext.implicits._
import org.apache.spark.sql._
import org.apache.spark.sql.{functions => func, _}
import org.apache.spark.sql.types._
import org.apache.spark.rdd.RDD
import org.apache.spark.sql.SparkSession
import org.apache.spark.sql.types.{IntegerType, StringType, StructType}
import org.apache.spark.{SparkConf, SparkContext}
import org.apache.spark._
import org.apache.spark.sql.types._, func._
import org.apache.spark.sql.functions.{col, to_date}
import plotly._
import plotly.element._
import plotly.layout._
import plotly.Almond._
import org.apache.spark.sql.types.DateType
// Out:
// import spark.implicits._
//
// import spark.sqlContext.implicits._
//
// import org.apache.spark.sql._
//
// import org.apache.spark.sql.{functions => func, _}
//
// import org.apache.spark.sql.types._
//
// import org.apache.spark.rdd.RDD
//
// import org.apache.spark.sql.SparkSession
//
// import org.apache.spark.sql.types.{IntegerType, StringType, StructType}
//
// import org.apache.spark.{SparkConf, SparkContext}
//
// import org.apache.spark._
//
// import org.apache.spark.sql.types._, func._
//
// import org.apache.spark.sql.functions.{col, to_date}
//
// import plotly._
//
// import plotly.element._
//
// import plotly.layout._
//
// import plotly.Almond._
//
// import org.apache.spark.sql.types.DateType

// %% [markdown]
// ## Consulta con DataSet

// %%
val infectionsDS = spark.read
.option("header", "true")
.option("charset", "UTF8")
.option("delimiter",",")
.option("inferSchema", "true")
.csv("../datasets/covid_19_data.csv")
.as[(Int,String,String,String,String,Double,Double,Double)]
// Out:
// <script>
// var comm = Jupyter.notebook.kernel.comm_manager.new_comm('cancel-stage-e236ba86-4b96-4450-b643-58f3803b4bfc', {});
//
// function cancelStage(stageId) {
//   console.log('Cancelling stage ' + stageId);
//   comm.send({ 'stageId': stageId });
// }
// </script>
// <div>
//   <span style="float: left;">csv at cmd2.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">csv at cmd2.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// infectionsDS: Dataset[(Int, String, String, String, String, Double, Double, Double)] = [SNo: int, ObservationDate: string ... 6 more fields]

// %%
val populationDS = spark.read
.option("header", "true")
.option("charset", "UTF8")
.option("delimiter",",")
.option("inferSchema", "true")
.csv("../datasets/population_by_country_2020.csv")
.withColumnRenamed("Country (or dependency)","Country")
.withColumnRenamed("Population (2020)","Population")
.as[(String,Float,String,Float,Float,Float,Double,String,String,String,String)]
// Out:
// <div>
//   <span style="float: left;">csv at cmd3.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">csv at cmd3.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// populationDS: Dataset[(String, Float, String, Float, Float, Float, Double, String, String, String, String)] = [Country: string, Population: int ... 9 more fields]

// %%
val vaccinationsDS = spark.read
.option("header", "true")
.option("charset", "UTF8")
.option("delimiter",",")
.option("inferSchema", "true")
.csv("../datasets/country_vaccinations.csv")
.as[(String,String,java.sql.Timestamp,Double,Double,Double,Double,Double,Double,Double,Double,Double,String,String,String)]
// Out:
// <div>
//   <span style="float: left;">csv at cmd4.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">csv at cmd4.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// vaccinationsDS: Dataset[(String, String, java.sql.Timestamp, Double, Double, Double, Double, Double, Double, Double, Double, Double, String, String, String)] = [country: string, iso_code: string ... 13 more fields]

// %% [markdown]
// modifico los datos de entrada para que se ajuste la fecha

// %%
val vaccinationsClean = vaccinationsDS
    .select($"*",col("date"),to_date(col("date"),"MM-dd-yyyy")
            .as("dateVaccinated"))
    .drop("date")
// Out:
// vaccinationsClean: DataFrame = [country: string, iso_code: string ... 13 more fields]

// %%
val dateInfectionsDS = infectionsDS
    .select($"*",$"ObservationDate",translate($"ObservationDate","/","-")
            .as("date1"))
    .drop("ObservationDate")
    .select($"*",col("date1"),to_date(col("date1"),"MM-dd-yyyy")
            .as("date"))
    .drop("date1")
    .as[(Int,String,String,String,Double,Double,Double,java.sql.Timestamp)]
// Out:
// dateInfectionsDS: Dataset[(Int, String, String, String, Double, Double, Double, java.sql.Timestamp)] = [SNo: int, Province/State: string ... 6 more fields]

// %%
dateInfectionsDS.join(
    vaccinationsClean,$"date" === $"dateVaccinated"
    && dateInfectionsDS("Country/Region") <=> vaccinationsClean("country")
).join(populationDS, "country")
// Out:
// res7: DataFrame = [country: string, SNo: int ... 31 more fields]

// %%
val megaDS = dateInfectionsDS.join(
    vaccinationsClean,$"date" === $"dateVaccinated"
    && dateInfectionsDS("Country/Region") <=> vaccinationsClean("country")
).join(populationDS,"country")
        .na.fill(0)
        .select($"country",
                $"date",
                $"confirmed",
                $"people_vaccinated",
                $"Population",
                $"confirmed" / $"Population" as "infection Per Population",
                $"people_vaccinated"/ $"Population" as "vaccination Per Population",
                $"people_vaccinated" / $"confirmed" as "infection-vaccination rate")
        .orderBy($"date".asc)
        .withColumn("infection-vaccination rate", round($"infection-vaccination rate",8))
        .withColumn("vaccination Per Population", round($"vaccination Per Population",8))
//        .as[(String,java.sql.Timestamp,Double,Double,Int,Double,Double,Double)]
// Out:
// megaDS: DataFrame = [country: string, date: date ... 6 more fields]

// %%
ch.cern.sparkmeasure.StageMetrics(spark).runAndMeasure(
    megaDS.collect
    )
// Out:
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd9.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd9.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd9.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd9.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     129 / 129
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// Time taken: 4552 ms
// <div>
//   <span style="float: left;">take at stagemetrics.scala:207</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     6 / 6
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">take at stagemetrics.scala:207</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// Scheduling mode = FIFO
// Spark Context default degree of parallelism = 6
// Aggregated Spark stage metrics:
// numStages => 6
// numTasks => 142
// elapsedTime => 4144 (4 s)
// stageDuration => 3790 (4 s)
// executorRunTime => 11629 (12 s)
// executorCpuTime => 6934 (7 s)
// executorDeserializeTime => 2196 (2 s)
// executorDeserializeCpuTime => 813 (0.8 s)
// resultSerializationTime => 67 (67 ms)
// jvmGCTime => 442 (0.4 s)
// shuffleFetchWaitTime => 0 (0 ms)
// shuffleWriteTime => 84 (84 ms)
// resultSize => 2683269 (2.0 MB)
// diskBytesSpilled => 0 (0 Bytes)
// memoryBytesSpilled => 0 (0 Bytes)
// peakExecutionMemory => 276889600
// recordsRead => 647465
// bytesRead => 50729325 (48.0 MB)
// recordsWritten => 0
// bytesWritten => 0 (0 Bytes)
// shuffleRecordsRead => 64698
// shuffleTotalBlocksFetched => 130
// shuffleLocalBlocksFetched => 130
// shuffleRemoteBlocksFetched => 0
// shuffleTotalBytesRead => 2175209 (2.0 MB)
// shuffleLocalBytesRead => 2175209 (2.0 MB)
// shuffleRemoteBytesRead => 0 (0 Bytes)
// shuffleRemoteBytesReadToDisk => 0 (0 Bytes)
// shuffleBytesWritten => 2175209 (2.0 MB)
// shuffleRecordsWritten => 64698
// res9: Array[Row] = Array(
//   [Norway,2020-12-02,36969.0,1.0,5428594,0.006810050631894741,1.8E-7,2.705E-5],
//   [Norway,2020-12-03,37371.0,1.0,5428594,0.0068841029555719215,1.8E-7,2.676E-5],
//   [Norway,2020-12-04,37801.0,2.0,5428594,0.00696331315254005,3.7E-7,5.291E-5],
//   [Norway,2020-12-05,38073.0,2.0,5428594,0.0070134182073664005,3.7E-7,5.253E-5],
//   [Norway,2020-12-06,38323.0,2.0,5428594,0.00705947064746415,3.7E-7,5.219E-5],
//   [Norway,2020-12-07,38703.0,4.0,5428594,0.007129470356412729,7.4E-7,1.0335E-4],
//   [Norway,2020-12-08,39163.0,4.0,5428594,0.007214206846192587,7.4E-7,1.0214E-4],
//   [Norway,2020-12-09,39525.0,5.0,5428594,0.007280890779454128,9.2E-7,1.265E-4],
//   [Norway,2020-12-10,40023.0,6.0,5428594,0.0073726272401288435,1.11E-6,1.4991E-4],
//   [Norway,2020-12-11,40439.0,7.0,5428594,0.007449258500451498,1.29E-6,1.731E-4],
//   [Norway,2020-12-12,40803.0,7.0,5428594,0.00751631085323382,1.29E-6,1.7156E-4],
//   [Norway,2020-12-13,41003.0,7.0,5428594,0.00755315280531202,1.29E-6,1.7072E-4],
//   [Norway,2020-12-14,41334.0,7.0,5428594,0.0076141262360014395,1.29E-6,1.6935E-4],
//   [Canada,2020-12-14,81986.0,0.0,37799407,0.002168975825467315,0.0,0.0],
//   [Canada,2020-12-14,42943.0,0.0,37799407,0.0011360760236265083,0.0,0.0],
//   [Canada,2020-12-14,0.0,0.0,37799407,0.0,0.0,null],
//   [Canada,2020-12-14,13.0,0.0,37799407,3.4392073928567187E-7,0.0,0.0],
//   [Canada,2020-12-14,21264.0,0.0,37799407,5.625485077054251E-4,0.0,0.0],
//   [Canada,2020-12-14,558.0,0.0,37799407,1.4762136347800377E-5,0.0,0.0],
//   [Canada,2020-12-14,358.0,0.0,37799407,9.471048051097733E-6,0.0,0.0],
//   [Canada,2020-12-14,21.0,0.0,37799407,5.555642711537776E-7,0.0,0.0],
//   [Canada,2020-12-14,1420.0,0.0,37799407,3.7566726906588774E-5,0.0,0.0],
//   [Canada,2020-12-14,256.0,0.0,37799407,6.772593019779384E-6,0.0,0.0],
//   [Canada,2020-12-14,146067.0,0.0,37799407,0.0038642669711723256,0.0,0.0],
//   [Canada,2020-12-14,89.0,0.0,37799407,2.354534292032677E-6,0.0,0.0],
//   [Canada,2020-12-14,165535.0,0.0,37799407,0.004379301505973361,0.0,0.0],
//   [Canada,2020-12-14,13.0,0.0,37799407,3.4392073928567187E-7,0.0,0.0],
//   [Canada,2020-12-14,12238.0,0.0,37799407,3.2376169287523477E-4,0.0,0.0],
//   [Canada,2020-12-14,59.0,0.0,37799407,1.56087104752728E-6,0.0,0.0],
//   [Norway,2020-12-15,41852.0,7.0,5428594,0.007709546891883976,1.29E-6,1.6726E-4],
//   [Russia,2020-12-15,9542.0,28500.0,145945524,6.538055939283208E-5,1.9528E-4,2.98679522],
//   [Canada,2020-12-15,83327.0,0.0,37799407,0.0022044525724967063,0.0,0.0],
//   [Russia,2020-12-15,29463.0,28500.0,145945524,2.0187669475906642E-4,1.9528E-4,0.96731494],
// ...

// %% [markdown]
// ## Consulta con DataFrame

// %%
val infectionsDF = spark.read
.option("header", "true")
.option("charset", "UTF8")
.option("delimiter",",")
.option("inferSchema", "true")
.csv("../datasets/covid_19_data.csv")
// Out:
// <div>
//   <span style="float: left;">csv at cmd10.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">csv at cmd10.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// infectionsDF: DataFrame = [SNo: int, ObservationDate: string ... 6 more fields]

// %%
val populationDF = spark.read
.option("header", "true")
.option("charset", "UTF8")
.option("delimiter",",")
.option("inferSchema", "true")
.csv("../datasets/population_by_country_2020.csv")
.withColumnRenamed("Country (or dependency)","Country")
.withColumnRenamed("Population (2020)","Population")
// Out:
// <div>
//   <span style="float: left;">csv at cmd11.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">csv at cmd11.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// populationDF: DataFrame = [Country: string, Population: int ... 9 more fields]

// %%
val vaccinationsDF = spark.read
.option("header", "true")
.option("charset", "UTF8")
.option("delimiter",",")
.option("inferSchema", "true")
.csv("../datasets/country_vaccinations.csv")
// Out:
// <div>
//   <span style="float: left;">csv at cmd12.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">csv at cmd12.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// vaccinationsDF: DataFrame = [country: string, iso_code: string ... 13 more fields]

// %%
val vaccinationsClean = vaccinationsDF
    .select($"*",col("date"),to_date(col("date"),"MM-dd-yyyy")
            .as("dateVaccinated"))
    .drop("date")
// Out:
// vaccinationsClean: DataFrame = [country: string, iso_code: string ... 13 more fields]

// %%
val dateInfectionsDS = infectionsDS
    .select($"*",$"ObservationDate",translate($"ObservationDate","/","-")
            .as("date1"))
    .drop("ObservationDate")
    .select($"*",col("date1"),to_date(col("date1"),"MM-dd-yyyy")
            .as("date"))
    .drop("date1")
// Out:
// dateInfectionsDS: DataFrame = [SNo: int, Province/State: string ... 6 more fields]

// %%
val megaDF = dateInfectionsDS.join(
    vaccinationsClean,$"date" === $"dateVaccinated"
    && dateInfectionsDS("Country/Region") <=> vaccinationsClean("country")
).join(populationDF,"country")
        .select($"country",
                $"date",
                $"confirmed",
                $"people_vaccinated",
                $"Population",
                $"confirmed" / $"Population" as "infection Per Population",
                $"people_vaccinated"/ $"Population" as "vaccination Per Population",
                $"people_vaccinated" / $"confirmed" as "infection-vaccination rate")
        .orderBy($"date".asc)
        .na.fill(0)
        .withColumn("infection-vaccination rate", round($"infection-vaccination rate",8))
        .withColumn("vaccination Per Population", round($"vaccination Per Population",8))
// Out:
// megaDF: DataFrame = [country: string, date: date ... 6 more fields]

// %%
ch.cern.sparkmeasure.StageMetrics(spark).runAndMeasure(
megaDF.collect
)
// Out:
// <div>
//   <span style="float: left;">collect at cmd19.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     129 / 129
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// Time taken: 475 ms
// <div>
//   <span style="float: left;">take at stagemetrics.scala:207</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">take at stagemetrics.scala:207</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// Scheduling mode = FIFO
// Spark Context default degree of parallelism = 6
// Aggregated Spark stage metrics:
// numStages => 1
// numTasks => 129
// elapsedTime => 411 (0.4 s)
// stageDuration => 411 (0.4 s)
// executorRunTime => 1001 (1 s)
// executorCpuTime => 446 (0.4 s)
// executorDeserializeTime => 910 (0.9 s)
// executorDeserializeCpuTime => 408 (0.4 s)
// resultSerializationTime => 11 (11 ms)
// jvmGCTime => 65 (65 ms)
// shuffleFetchWaitTime => 0 (0 ms)
// shuffleWriteTime => 0 (0 ms)
// resultSize => 2678725 (2.0 MB)
// diskBytesSpilled => 0 (0 Bytes)
// memoryBytesSpilled => 0 (0 Bytes)
// peakExecutionMemory => 276889600
// recordsRead => 0
// bytesRead => 0 (0 Bytes)
// recordsWritten => 0
// bytesWritten => 0 (0 Bytes)
// shuffleRecordsRead => 64698
// shuffleTotalBlocksFetched => 130
// shuffleLocalBlocksFetched => 130
// shuffleRemoteBlocksFetched => 0
// shuffleTotalBytesRead => 2224011 (2.0 MB)
// shuffleLocalBytesRead => 2224011 (2.0 MB)
// shuffleRemoteBytesRead => 0 (0 Bytes)
// shuffleRemoteBytesReadToDisk => 0 (0 Bytes)
// shuffleBytesWritten => 0 (0 Bytes)
// shuffleRecordsWritten => 0
// res19: Array[Row] = Array(
//   [Norway,2020-12-02,36969.0,1.0,5428594,0.006810050631894741,1.8E-7,2.705E-5],
//   [Norway,2020-12-03,37371.0,1.0,5428594,0.0068841029555719215,1.8E-7,2.676E-5],
//   [Norway,2020-12-04,37801.0,2.0,5428594,0.00696331315254005,3.7E-7,5.291E-5],
//   [Norway,2020-12-05,38073.0,2.0,5428594,0.0070134182073664005,3.7E-7,5.253E-5],
//   [Norway,2020-12-06,38323.0,2.0,5428594,0.00705947064746415,3.7E-7,5.219E-5],
//   [Norway,2020-12-07,38703.0,4.0,5428594,0.007129470356412729,7.4E-7,1.0335E-4],
//   [Norway,2020-12-08,39163.0,4.0,5428594,0.007214206846192587,7.4E-7,1.0214E-4],
//   [Norway,2020-12-09,39525.0,5.0,5428594,0.007280890779454128,9.2E-7,1.265E-4],
//   [Norway,2020-12-10,40023.0,6.0,5428594,0.0073726272401288435,1.11E-6,1.4991E-4],
//   [Norway,2020-12-11,40439.0,7.0,5428594,0.007449258500451498,1.29E-6,1.731E-4],
//   [Norway,2020-12-12,40803.0,7.0,5428594,0.00751631085323382,1.29E-6,1.7156E-4],
//   [Norway,2020-12-13,41003.0,7.0,5428594,0.00755315280531202,1.29E-6,1.7072E-4],
//   [Norway,2020-12-14,41334.0,7.0,5428594,0.0076141262360014395,1.29E-6,1.6935E-4],
//   [Canada,2020-12-14,81986.0,0.0,37799407,0.002168975825467315,0.0,0.0],
//   [Canada,2020-12-14,42943.0,0.0,37799407,0.0011360760236265083,0.0,0.0],
//   [Canada,2020-12-14,0.0,0.0,37799407,0.0,0.0,0.0],
//   [Canada,2020-12-14,13.0,0.0,37799407,3.4392073928567187E-7,0.0,0.0],
//   [Canada,2020-12-14,21264.0,0.0,37799407,5.625485077054251E-4,0.0,0.0],
//   [Canada,2020-12-14,558.0,0.0,37799407,1.4762136347800377E-5,0.0,0.0],
//   [Canada,2020-12-14,358.0,0.0,37799407,9.471048051097733E-6,0.0,0.0],
//   [Canada,2020-12-14,21.0,0.0,37799407,5.555642711537776E-7,0.0,0.0],
//   [Canada,2020-12-14,1420.0,0.0,37799407,3.7566726906588774E-5,0.0,0.0],
//   [Canada,2020-12-14,256.0,0.0,37799407,6.772593019779384E-6,0.0,0.0],
//   [Canada,2020-12-14,146067.0,0.0,37799407,0.0038642669711723256,0.0,0.0],
//   [Canada,2020-12-14,89.0,0.0,37799407,2.354534292032677E-6,0.0,0.0],
//   [Canada,2020-12-14,165535.0,0.0,37799407,0.004379301505973361,0.0,0.0],
//   [Canada,2020-12-14,13.0,0.0,37799407,3.4392073928567187E-7,0.0,0.0],
//   [Canada,2020-12-14,12238.0,0.0,37799407,3.2376169287523477E-4,0.0,0.0],
//   [Canada,2020-12-14,59.0,0.0,37799407,1.56087104752728E-6,0.0,0.0],
//   [Norway,2020-12-15,41852.0,7.0,5428594,0.007709546891883976,1.29E-6,1.6726E-4],
//   [Russia,2020-12-15,9542.0,28500.0,145945524,6.538055939283208E-5,1.9528E-4,2.98679522],
//   [Canada,2020-12-15,83327.0,0.0,37799407,0.0022044525724967063,0.0,0.0],
//   [Russia,2020-12-15,29463.0,28500.0,145945524,2.0187669475906642E-4,1.9528E-4,0.96731494],
// ...

// %% [markdown]
// # Visualización de datos con plotly

// %% [markdown]
// ## crecimiento de la vacunacion con respecto a la densidad población

// %%
val y = megaDF.filter($"country" === "Chile").select($"vaccination Per Population" * 10000000).
    collect.map(r => r(0).toString.toDouble).toList

val x = megaDF.filter($"country" === "Chile").select($"date").collect.toList.map(_.toString)

val y1 = megaDF.filter($"country" === "Chile").select($"people_vaccinated").
    collect.map(r => r(0).toString.toDouble).toList
val x1 = megaDF.filter($"country" === "Chile").select($"date").collect.toList.map(_.toString)

val data = Seq(
    Scatter(x,y).withName("% population"),
    Scatter(x1,y1).withName("Vaccines administrated")
).map(_.withFill(Fill.ToNextY).withStackgroup("A"))

val myLayout =
  Layout()
    .withTitle("CHILE")

plot(data,myLayout)
// Out:
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:1</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:1</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:1</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     131 / 131
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:4</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:4</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:4</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     131 / 131
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:6</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     131 / 131
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:8</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:8</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     5 / 5
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">collect at cmd17.sc:8</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     131 / 131
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
//       <script type="text/javascript">
//         require.config({
//   paths: {
//     d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3.min',
//     plotly: 'https://cdn.plot.ly/plotly-1.52.2.min',
//     jquery: 'https://code.jquery.com/jquery-3.3.1.min'
//   },
//
//   shim: {
//     plotly: {
//       deps: ['d3', 'jquery'],
//       exports: 'plotly'
//     }
//   }
// });
//
//
//         require(['plotly'], function(Plotly) {
//           window.Plotly = Plotly;
//         });
//       </script>
// <div class="chart" id="plot-35600057-f326-4cca-adf5-03df6e4873c4"></div>
// <script>require(['plotly'], function(Plotly) {
//   (function () {
//   var data0 = {"x":["[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-24]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-25]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-26]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-27]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-28]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-29]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-30]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2020-12-31]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-01]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-02]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-03]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-04]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-05]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-06]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-07]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[2021-01-08]","[202 ...
// y: List[Double] = List(
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   219.4,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   2715.1,
//   4355.3,
//   4355.3,
//   4355.3,
//   4355.3,
// ...
// x: List[String] = List(
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-26]",
//   "[2020-12-26]",
//   "[2020-12-26]",
//   "[2020-12-26]",
// ...
// y1: List[Double] = List(
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   420.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   5198.0,
//   8338.0,
//   8338.0,
//   8338.0,
//   8338.0,
// ...
// x1: List[String] = List(
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-24]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-25]",
//   "[2020-12-26]",
//   "[2020-12-26]",
//   "[2020-12-26]",
//   "[2020-12-26]",
// ...
// data: Seq[Scatter] = List(
//   Scatter(
//     Some(
//       Strings(
//         List(
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-24]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
//           "[2020-12-25]",
// ...
// myLayout: Layout = Layout(
//   Some("CHILE"),
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None,
//   None
// )
// res17_6: String = "plot-35600057-f326-4cca-adf5-03df6e4873c4"

// %% [markdown]
// # Visualización de eficiencia

// %%
val (x, y) = Seq(
    "DataSet" -> runWithOutput(megaDS.collect),
    "DataFrame" -> runWithOutput(megaDF.collect),
).unzip

Bar(x, y).plot()
// Out:
// <div>
//   <span style="float: left;">collect at cmd18.sc:2</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     129 / 129
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// Took 684
// <div>
//   <span style="float: left;">collect at cmd18.sc:3</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     129 / 129
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// Took 624
// <div class="chart" id="plot-7452a756-6c6b-4cd2-ab37-dd287cac2d39"></div>
// <script>require(['plotly'], function(Plotly) {
//   (function () {
//   var data0 = {"x":["DataSet","DataFrame"],"y":[684.0,624.0],"type":"bar"};
//
//   var data = [data0];
//   var layout = {};
//  var config = {};
//
//   Plotly.plot('plot-7452a756-6c6b-4cd2-ab37-dd287cac2d39', data, layout, config);
// })();
// });
//       </script>
// x: Seq[String] = List("DataSet", "DataFrame")
// y: Seq[Int] = List(684, 624)
// res18_1: String = "plot-7452a756-6c6b-4cd2-ab37-dd287cac2d39"
